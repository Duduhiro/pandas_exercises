# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
chipo_filtered = chipo.drop_duplicates(['item_name', 'quantity', 'choice_description'])
chipo_one_prod = chipo_filtered[chipo_filtered.quantity == 1]

chipo.query('item_price > 10').item_name.nunique()
# Out:
# 31

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
chipo.query('item_price > 10')
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.query('item_price > 10').sort_values('item_name')
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 1643       664         1      Barbacoa Bowl
# 919        380         1      Barbacoa Bowl
# 3547      1426         1      Barbacoa Bowl
# 4510      1793         1      Barbacoa Bowl
# ...        ...       ...                ...
# 186         83         1  Veggie Salad Bowl
# 295        128         1  Veggie Salad Bowl
# 3889      1559         2  Veggie Soft Tacos
# 738        304         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 1643  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...       11.75
# 919   [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 3547  [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream...       11.75
# 4510                                        [Guacamole]       11.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.groupby(['item_name', 'item_price'])['quantity'].sum().reset_index().sort_values('item_price', ascending=False)
# Out:
#                         item_name  item_price  quantity
# 123  Chips and Fresh Tomato Salsa       44.25        15
# 51                  Carnitas Bowl       35.25         3
# 93                Chicken Burrito       35.00         8
# 200                Veggie Burrito       33.75         3
# 81                   Chicken Bowl       32.94         3
# ..                            ...         ...       ...
# 151                 Side of Chips        1.69        99
# 26                  Bottled Water        1.50       117
# 41              Canned Soft Drink        1.25       264
# 25                  Bottled Water        1.09        22
# 38                    Canned Soda        1.09        84
#
# [209 rows x 3 columns]

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo.loc[chipo['item_name'] == 'Veggie Salad Bowl', :].count()
# Out:
# order_id              18
# quantity              18
# item_name             18
# choice_description    18
# item_price            18
# dtype: int64

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
chipo.loc[(chipo['item_name'] == 'Canned Soda') & (chipo['quantity'] > 1), :].count()
# Out:
# order_id              20
# quantity              20
# item_name             20
# choice_description    20
# item_price            20
# dtype: int64
