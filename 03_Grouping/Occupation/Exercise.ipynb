# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep='|')

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
users.groupby('occupation')['age'].mean().reset_index()
# Out:
#        occupation        age
# 0   administrator  38.746835
# 1          artist  31.392857
# 2          doctor  43.571429
# 3        educator  42.010526
# 4        engineer  36.388060
# 5   entertainment  29.222222
# 6       executive  38.718750
# 7      healthcare  41.562500
# 8       homemaker  32.571429
# 9          lawyer  36.750000
# 10      librarian  40.000000
# 11      marketing  37.615385
# 12           none  26.555556
# 13          other  34.523810
# 14     programmer  33.121212
# 15        retired  63.071429
# 16       salesman  35.666667
# 17      scientist  35.548387
# 18        student  22.081633
# 19     technician  33.148148
# 20         writer  36.311111

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
gender_count = users.groupby('occupation')['gender'].count().reset_index().rename(columns={'gender': 'total_count'})

male_count = users.groupby(['occupation', 'gender'])['age'].count().reset_index()
male_count = male_count[male_count['gender'] == 'M'].rename(columns={'age': 'male_count'})
male_count = male_count.merge(gender_count, on='occupation')

male_count['male_ratio'] = male_count['male_count'] / male_count['total_count'] * 100

male_count.set_index('occupation')['male_ratio'].sort_values(ascending=False)
# Out:
# occupation
# doctor           100.000000
# engineer          97.014925
# technician        96.296296
# retired           92.857143
# programmer        90.909091
# executive         90.625000
# scientist         90.322581
# entertainment     88.888889
# lawyer            83.333333
# salesman          75.000000
# educator          72.631579
# student           69.387755
# other             65.714286
# marketing         61.538462
# writer            57.777778
# none              55.555556
# administrator     54.430380
# artist            53.571429
# librarian         43.137255
# healthcare        31.250000
# homemaker         14.285714
# Name: male_ratio, dtype: float64

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
users.groupby('occupation')['age'].agg(['min', 'max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
users.groupby(['occupation', 'gender'])['age'].mean().reset_index()
# Out:
#        occupation gender        age
# 0   administrator      F  40.638889
# 1   administrator      M  37.162791
# 2          artist      F  30.307692
# 3          artist      M  32.333333
# 4          doctor      M  43.571429
# 5        educator      F  39.115385
# 6        educator      M  43.101449
# 7        engineer      F  29.500000
# 8        engineer      M  36.600000
# 9   entertainment      F  31.000000
# 10  entertainment      M  29.000000
# 11      executive      F  44.000000
# 12      executive      M  38.172414
# 13     healthcare      F  39.818182
# 14     healthcare      M  45.400000
# 15      homemaker      F  34.166667
# 16      homemaker      M  23.000000
# 17         lawyer      F  39.500000
# 18         lawyer      M  36.200000
# 19      librarian      F  40.000000
# 20      librarian      M  40.000000
# 21      marketing      F  37.200000
# 22      marketing      M  37.875000
# 23           none      F  36.500000
# 24           none      M  18.600000
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
male_count['female_ratio'] = 100 - male_count['male_ratio']
male_count
# Out:
#        occupation gender  male_count  total_count  male_ratio  female_ratio
# 0   administrator      M          43           79   54.430380     45.569620
# 1          artist      M          15           28   53.571429     46.428571
# 2          doctor      M           7            7  100.000000      0.000000
# 3        educator      M          69           95   72.631579     27.368421
# 4        engineer      M          65           67   97.014925      2.985075
# 5   entertainment      M          16           18   88.888889     11.111111
# 6       executive      M          29           32   90.625000      9.375000
# 7      healthcare      M           5           16   31.250000     68.750000
# 8       homemaker      M           1            7   14.285714     85.714286
# 9          lawyer      M          10           12   83.333333     16.666667
# 10      librarian      M          22           51   43.137255     56.862745
# ...
